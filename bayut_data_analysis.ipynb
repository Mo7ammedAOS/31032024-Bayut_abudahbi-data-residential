# %%
import pandas as pd

# %%
bayut_df = pd.read_csv('bayut_data_abudhabi.csv')
bayut_df
# Out:
#        price                                           location  area
# 0    3650000      Al Barza, Al Bandar, Al Raha Beach, Abu Dhabi  2035
# 1    3650000      Al Barza, Al Bandar, Al Raha Beach, Abu Dhabi  2035
# 2    3650000      Al Barza, Al Bandar, Al Raha Beach, Abu Dhabi  2035
# 3     885000  Burooj Views, Marina Square, Al Reem Island, A...   861
# 4     885000  Burooj Views, Marina Square, Al Reem Island, A...   861
# ..       ...                                                ...   ...
# 191  1000000                Water's Edge, Yas Island, Abu Dhabi   699
# 192  1270000              Reem Hills, Al Reem Island, Abu Dhabi  1331
# 193  1270000              Reem Hills, Al Reem Island, Abu Dhabi  1331
# 194  2836056                Gardenia Bay, Yas Island, Abu Dhabi  1590
# 195  2836056                Gardenia Bay, Yas Island, Abu Dhabi  1590
#
# [196 rows x 3 columns]

# %%
bayut_df.value_counts().head(15).plot(kind='barh')
# Out:
# <Axes: ylabel='price,location,area'>

# %%
bayut_df.value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
